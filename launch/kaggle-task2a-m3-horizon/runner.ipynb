# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !echo '--- /kaggle/input structure ---' && find /kaggle/input -maxdepth 4 && mkdir -p /kaggle/working/s4dpc/results/all_cases/ckpt && find /kaggle/input -type f \( -name '*.msgpack' -o -name '*.json' \) -exec cp {} /kaggle/working/s4dpc/results/all_cases/ckpt/ \; && echo '--- copied count ---' && ls /kaggle/working/s4dpc/results/all_cases/ckpt | wc -l

# %%
# !cd /kaggle/working/s4dpc && python tools/task2a_m3_horizon_ablation.py
