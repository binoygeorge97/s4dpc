# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !python -c "import numpy; print('pre-install numpy:', numpy.__version__)"

# %%
# Kaggle preinstalls a base jax; this can replace it with the pinned version.
# Safe here because every jax-importing step below runs in its own fresh
# `python` subprocess, so there is no stale-import / restart-kernel issue.
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock
# !pip freeze > /kaggle/working/resolved_requirements.txt
# !cat /kaggle/working/resolved_requirements.txt

# %%
# !cd /kaggle/working/s4dpc && python env_probe.py | tee /kaggle/working/env_probe.json

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep \
    --variant M6 --cases 3 --n_seeds 2 --epochs 50 \
    --wandb off --out /kaggle/working/out.csv

# %%
# !cat /kaggle/working/out.csv
