# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !mkdir -p /kaggle/working/s4dpc/results/all_cases/ckpt && cp /kaggle/input/s4dpc-controller-task3-ckpt/* /kaggle/working/s4dpc/results/all_cases/ckpt/ && ls /kaggle/working/s4dpc/results/all_cases/ckpt | wc -l

# %%
# !cd /kaggle/working/s4dpc && python tools/pilot_controller_surrogates.py
