# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !cd /kaggle/working/s4dpc && python env_probe.py > /kaggle/working/env_probe_kaggle_t4.json && cat /kaggle/working/env_probe_kaggle_t4.json
