# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M3 --cases 1,2,3,4,5,6,7 --n_seeds 10 --epochs 40000 --d_model 16 --N 32 --n_layers 1 --wandb off --out results/all_cases/M3.csv

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M6 --cases 1,2,3,4,5,6,7 --n_seeds 10 --epochs 40000 --d_model 16 --N 32 --n_layers 1 --wandb off --out results/all_cases/M6.csv

# %%
# !cd /kaggle/working/s4dpc && python tools/diagnose_all_cases_10seeds.py
