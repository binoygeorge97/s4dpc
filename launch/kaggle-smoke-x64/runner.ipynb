# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M3 --cases 3 --n_seeds 1 --epochs 2000 --d_model 16 --N 32 --n_layers 1 --wandb off --out out_smoke_x64/m3_x64.csv

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M3 --cases 3 --n_seeds 1 --epochs 2000 --d_model 16 --N 32 --n_layers 1 --wandb off --no-x64 --out out_smoke_x64/m3_f32.csv

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M6 --cases 3 --n_seeds 1 --epochs 2000 --d_model 16 --N 32 --n_layers 1 --wandb off --out out_smoke_x64/m6_x64.csv

# %%
# !cd /kaggle/working/s4dpc && python -m s4dpc.sweep --variant M6 --cases 3 --n_seeds 1 --epochs 2000 --d_model 16 --N 32 --n_layers 1 --wandb off --no-x64 --out out_smoke_x64/m6_f32.csv

# %%
# !cd /kaggle/working/s4dpc && python tools/compare_x64_smoke.py
