# %%
# !git clone https://github.com/binoygeorge97/s4dpc.git /kaggle/working/s4dpc

# %%
# !pip install -q -r /kaggle/working/s4dpc/requirements.lock

# %%
# !cd /kaggle/working/s4dpc && python tools/diagnose_m3_asymptotic.py

# %%
# !cp /kaggle/working/s4dpc/docs/m3_d_only_50k_loglog.png /kaggle/working/m3_d_only_50k_loglog.png
